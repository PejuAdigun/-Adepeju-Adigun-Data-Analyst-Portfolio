# %% [markdown]
# IMPORTING THE NECESSARY LIBARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# LOADING THE CSV FILE

# %%
netflix_ds = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# Now, for some cleaing and EDA(Exploratory Data Analysis)

# %%
netflix_ds
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix_ds.shape
# Out:
# (8807, 12)

# %%
netflix_ds.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix_dt = netflix_ds[["show_id","type","title","release_year","rating","duration","listed_in","description"]]
netflix_dt
# Out:
#      show_id     type                  title  release_year rating   duration  \
# 0         s1    Movie   Dick Johnson Is Dead          2020  PG-13     90 min
# 1         s2  TV Show          Blood & Water          2021  TV-MA  2 Seasons
# 2         s3  TV Show              Ganglands          2021  TV-MA   1 Season
# 3         s4  TV Show  Jailbirds New Orleans          2021  TV-MA   1 Season
# 4         s5  TV Show           Kota Factory          2021  TV-MA  2 Seasons
# ...      ...      ...                    ...           ...    ...        ...
# 8802   s8803    Movie                 Zodiac          2007      R    158 min
# 8803   s8804  TV Show            Zombie Dumb          2018  TV-Y7  2 Seasons
# 8804   s8805    Movie             Zombieland          2009      R     88 min
# 8805   s8806    Movie                   Zoom          2006     PG     88 min
# 8806   s8807    Movie                 Zubaan          2015  TV-14    111 min
#
# ...

# %%
netflix_dt.shape
# Out:
# (8807, 8)

# %%
null_count = netflix_dt.isnull().sum()
null_count
# Out:
# show_id         0
# type            0
# title           0
# release_year    0
# rating          4
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
netflix_dt.rename(columns={'listed_in': 'genre'})
# Out:
#      show_id     type                  title  release_year rating   duration  \
# 0         s1    Movie   Dick Johnson Is Dead          2020  PG-13     90 min
# 1         s2  TV Show          Blood & Water          2021  TV-MA  2 Seasons
# 2         s3  TV Show              Ganglands          2021  TV-MA   1 Season
# 3         s4  TV Show  Jailbirds New Orleans          2021  TV-MA   1 Season
# 4         s5  TV Show           Kota Factory          2021  TV-MA  2 Seasons
# ...      ...      ...                    ...           ...    ...        ...
# 8802   s8803    Movie                 Zodiac          2007      R    158 min
# 8803   s8804  TV Show            Zombie Dumb          2018  TV-Y7  2 Seasons
# 8804   s8805    Movie             Zombieland          2009      R     88 min
# 8805   s8806    Movie                   Zoom          2006     PG     88 min
# 8806   s8807    Movie                 Zubaan          2015  TV-14    111 min
#
# ...

# %%
netflix_dt = netflix_dt.copy()  # Avoid SettingWithCopyWarning

# %%
# Fill missing ratings with "Not Rated"
netflix_dt['rating'].fillna('Not Rated', inplace=True)

# %%
# Fill missing durartion with "Not Included"
netflix_dt['duration'].fillna('Not Included', inplace=True)

# %%
null_count = netflix_dt.isnull().sum()
null_count
# Out:
# show_id         0
# type            0
# title           0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
duplicated = netflix_dt.duplicated()
duplicated
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# Changing the release_date column to a datetime type while handling any errors that could occur. We need this for further analysis of how many releases per year

# %%
netflix_dt['release_date'] = pd.to_datetime(netflix_dt['release_year'], format='%Y', errors='coerce')

# %%
# Group by year and count
releases_per_year = netflix_dt['release_year'].value_counts().sort_index()
releases_py = releases_per_year.reset_index()
releases_py.columns = ["Year", "Number of Releases"]
release_py_df = releases_py.columns

# %%
releases_py
# Out:
#     Year  Number of Releases
# 0   1925                   1
# 1   1942                   2
# 2   1943                   3
# 3   1944                   3
# 4   1945                   4
# ..   ...                 ...
# 69  2017                1032
# 70  2018                1147
# 71  2019                1030
# 72  2020                 953
# 73  2021                 592
#
# [74 rows x 2 columns]

# %%
# Plot
plt.figure(figsize=(12,6))
sns.barplot(data=releases_py,x="Year", y='Number of Releases', color='skyblue')
plt.title('Number of Netflix Releases per Year')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This is handling the genre column, to find out the distribution between each genre. By splitting it at each comma before exploding it into different rows, then counting each occurence of the genre.

# %%
genre = netflix_dt["listed_in"].str.split(',')
genres_exploded = genre.explode()
genre_counts = genres_exploded.str.strip().value_counts()
genre_df = genre_counts.reset_index()
genre_df.columns = ['Genre', 'Count']

# %%
# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=genre_df.head(20), x='Genre', y='Count', palette='viridis')
plt.xticks(rotation=75)
plt.title('Top 20 Netflix Genres')
plt.show()

# %% [markdown]
# This is where we join the strings in description into a single long string and changing the type to string for word cloud. We join it because we have multiple text entries (one per row). But the WordCloud algorithm works best when you give it one continuous block of text

# %%
text = ' '.join(netflix_dt["description"].dropna().astype(str))

# %% [markdown]
# Installing wordcloud before importing it.

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, max_words=100).generate(text)

# Display the word cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud of Movie Descriptions')
plt.show()

# %%
type_count = netflix_dt["type"].value_counts()

# %%
type_count
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.barplot( x=type_count.index, y=type_count.values, palette='inferno')
plt.xticks(rotation=75)
plt.title('Type fo releases')
plt.show()
